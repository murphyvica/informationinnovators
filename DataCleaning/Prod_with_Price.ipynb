# %%
import pandas as pd

# %%
prod = pd.read_csv("data/products_price.csv")
pd.set_option('display.max_rows', None)
prod.head(5)
# Out:
#          asin  product_type parent_asin product_group   manufacturer  \
# 0  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 1  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 2  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 3  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 4  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 5  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 6  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 7  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 8  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
# 9  B01LR5SIRI             0  B09Q3YJW2P        Sports  Amazon Basics
#
#            brand   model        color                size  \
# 0  Amazon Basics  DB1001  Light Green  20-Pound, Set of 2
# 1  Amazon Basics  DB1001  Light Green  20-Pound, Set of 2
# ...
